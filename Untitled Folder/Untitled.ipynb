# %%
a=int(input("Enter Data: "))
binary=(bin(a)[2:])
length=len(binary)
count=0
x=0
y=0
b=(bin(0)[2:])
if(length>=5):
    while(x<=5):
        if(binary[x]==1):
            b[y]=binary[x]
            if(binary[x]==binary[x+1]==1):
                count=count+1
            else:
                count=0
            if(count==5):
                b=b+str(0)
                x=x+1
                continue
            x=x+1
            y=y+1
                
    else:
        b[y]=binary[x]
        y=y+1
        x=x+1
    '''while(x<=5):
        if(binary[x]==binary[x+1]==1):
           count=count+1
        if(count==5):
            b=str(binary[:x])+str(0)+str(binary[:x])
            count=0
        else:
            b=str(binary[:x])
        x=x+1
    while(x<=5):
        if(one==5):
            b=str(b)+0
            continue
            #b=str(binary[:x])+0+str(binary[x:])
        if(binary[x]==1):
            one=one+1
            b=str(b)+str(binary[x])
        else:
            one=0
            b=str(b)+str(binary[x])
        x=x+1'''
    print("Data Before Bit Stuffing ",binary)
    print("Data After Bit Stuffing: ",b) 
else:
    print("Data Before Bit Stuffing ",binary)
    print("Data After Bit Stuffing: ",binary)
